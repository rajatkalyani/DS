# %%
import os
os.chdir('/Users/rajatpa/Documents/DS/37_code_basics/py/matpltlib/2_format_strings')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('weather data')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted',marker='+',markersize=7)

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('weather data')
plt.plot(x,y,'g+-.')

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('weather data')
plt.plot(x,y,'rD-')

# %%
# the aplha parameters increase the transperncy
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('weather data')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted',marker='+',markersize=7,alpha=0.5)

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('weather data')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted',marker='+',markersize=7,alpha=1)

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('weather data')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted',marker='+',markersize=7,alpha=0.3)
