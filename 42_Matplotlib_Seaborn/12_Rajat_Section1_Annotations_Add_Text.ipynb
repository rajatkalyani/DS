# %%
import os
os.chdir("/Users/rajatpa/Documents/DS/42_Matplotlib_Seaborn")

# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#     }
# </style>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Rectangle
from matplotlib.patches import FancyBboxPatch
# We need Text artist
from matplotlib.text import Text
from matplotlib.text import Annotation
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
# we will learn how annotations work in the background.
# Let's add a text to an empty axes with annotation
annot = Annotation("dude", 
                   xy=(0.2, 0.2), # the coordinates we want to pinpoint
                   xytext=(0.5, 0.8), # coordinate of texts
                   arrowprops=dict(width=2)) # arrow


fig, ax = plt.subplots()


# Since this also belongs to 
# Texts container, we will call add_text method
an1 = ax._add_text(annot)

# %%
ax.annotate("Some string here", 
            xy=(0.8, 0.8), 
            xytext=(0.8, 0.1), 
            arrowprops=dict(arrowstyle='->', lw=3, color='r') )
fig
